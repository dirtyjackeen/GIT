# %% [markdown]
# # Week 27 (2nd July - 8nd July 2018) - Number of New Ads

# %%
#packages
import pandas as pd
import csv
import matplotlib as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm
import numpy as np
import seaborn as sns
from statsmodels.formula.api import ols
import glob
import pycountry
from datetime import datetime

#chaning the number of columns that are displayed. get will tell you how much. 
pd.set_option("display.max_columns",60)
pd.set_option("display.max_rows",1000)
sns.set_style("whitegrid")

#currency converter
from currency_converter import CurrencyConverter
c = CurrencyConverter('http://www.ecb.int/stats/eurofxref/eurofxref-hist.zip')

pd.options.mode.chained_assignment = None

cc={"total_y": "New Ads W25", "margin %_y": "Margin % W25", "total_x": "New Ads W26",
                                      "margin %_x": "Margin % W26"}

# %%
##### Cleaning

#1. Import most recent week
df_new = pd.read_excel("27_newads.xlsx")
df_prev = pd.read_excel("26_newads.xlsx")

#2.Create function to number new ads for both weeks
df_new["total"] = 0
df_prev["total"] = 0
def bim(x):
    if x["insert_time"] >= datetime(2018,6,25):
        return(x["total"] + 1)
    else:
        return(x["total"])
def bam(x):
    if x["insert_time"] >= datetime(2018,6,18):
        return(x["total"] + 1)
    else:
        return(x["total"])    
df_new["total"] = df_new.apply(bim, axis = 1)
df_prev["total"] = df_prev.apply(bam, axis = 1)

#3. Create Margin % function
def woo(x):
    if x["purchase"] == 0 and x["revenue"] >= 1:
        return(100)
    if x["purchase"] == 0 and x["revenue"] == 0:
        return(0)
    if x["purchase"] > 0 and x["revenue"] == 0:
        return(-100)
    else:
        return((x["margin"]/x["revenue"])*100)

#4. Drop crap
df_prev.drop(columns = ["id","status","real_budget","start_date","end_date","url","ad_set_campaign_id",
                          "margin_percentage","facebook_ad_set_id","facebook_ad_account_id","facebook_business_id",
                          "short_url","ad_url_domain_id"], inplace=True)
df_new.drop(columns = ["id","status","real_budget","start_date","end_date","url","ad_set_campaign_id",
                          "margin_percentage","facebook_ad_set_id","facebook_ad_account_id","facebook_business_id",
                          "short_url","ad_url_domain_id"], inplace=True)

# %% [markdown]
# # Other

# %% [markdown]
# ## Jeanine de Konnigh

# %%
df_jeanine1=df_new.loc[df_new["marketer_name"]=="Jeanine de Konnigh"]
df_jeanine1=df_jeanine1.groupby(by=['campaign_name']).sum()
df_jeanine1["margin %"] = df_jeanine1.apply(woo, axis=1)
df_jeanine1["margin %"] = df_jeanine1["margin %"].round(2)

df_jeanine2=df_prev.loc[df_prev["marketer_name"]=="Jeanine de Konnigh"]
df_jeanine2=df_jeanine2.groupby(by=['campaign_name']).sum()
df_jeanine2["margin %"] = df_jeanine2.apply(woo, axis=1)
df_jeanine2["margin %"] = df_jeanine2["margin %"].round(2)

df_jeanine = df_jeanine1.merge(df_jeanine2, how ="outer", on = ["campaign_name"])
df_jeanine = df_jeanine[["total_y","margin %_y","total_x","margin %_x"]]
df_jeanine = df_jeanine.rename(index=str, columns=cc)

df_jeanine["Margin % Difference from Previous Week"]=df_jeanine["Margin % W26"]-(df_jeanine["Margin % W25"])

df_jeanine
# Out:
#                                                     New Ads W25  Margin % W25  \
# campaign_name
# Afrika Museum Like                                          NaN           NaN
# Compare & Connect - Voucher LEAD ADS - KitchenAid           NaN           NaN
# Divina Pastora - Dental Insurance - Lead Ads                7.0         35.15
# Divina Pastora - Seguro Mascotas Lead Ads                   0.0         55.10
# Intereno NL - Messenger                                     NaN           NaN
# Intereno NL - RSP A/B test                                  6.0         61.24
# Museum Volkenkunde Like                                     NaN           NaN
# Twin Promotion - Boulogne Sur Mer BEFR - Lead Ads           NaN           NaN
# Twin Promotion - Ibis Brussels Airport BEFR                 NaN           NaN
# Twin Promotion - Ibis Brussels Airport BENL                 NaN           NaN
# Twin Promotion - Les Jardins d'Azur BEFR - lead...          NaN           NaN
# Twin Promotion - Les Jardins d'Azur BENL - lead...          NaN           NaN
# Twin Promotion - Trésors d’Opale BEFR - lead ads            NaN           NaN
# Twin Promotion - Trésors d’Opale BENL - lead ads            NaN           NaN
# Twin Properties - Holiday Suites NieuwPoort Res...          NaN           NaN
# Twin Properties - ibis Knokke BENL - Lead ads               2.0         52.35
# Upstairs BENL - Lead Ads                                    9.0        -37.02
# Upstairs BENL - Lead ads - Cities                          20.0          7.50
# Upstairs BENL - QZ Renovatieprofiel v2 - B                  4.0        -40.62
# Upstairs DE                                                 7.0         -7.97
# Upstairs DE - Lead Ads                                      8.0        -65.12
# Verisure Services (UK) Limited                              5.0        -21.37
# Verisure UK - Cities                                        NaN           NaN
# Wereldmuseum Rotterdam Like                                 NaN           NaN
# Compare & Connect - Lead ads - Voucher AU UD                3.0         45.95
# Intereno NL - LA Brochure Inspiratie                        4.0        -24.54
# Intereno NL - LA Brochure Tips                              4.0          4.09
# Intereno NL - LA Brochure Tips [Cities]                    20.0         15.89
# Intereno NL - RSP                                           5.0         14.95
# Twin Properties - Les Jardins d'Azur BENL - lea...          0.0         13.18
# Twin Properties - Trésors d’Opale BEFR - lead ads           0.0         66.54
# Twin Properties BEFR - Holiday Suites NieuwPoor...          0.0         25.99
# Upstairs BENL - QZ Renovatieprofiel v2                      0.0       -100.00
#
#                                                     New Ads W26  Margin % W26  \
# campaign_name
# Afrika Museum Like                                          5.0         32.05
# Compare & Connect - Voucher LEAD ADS - KitchenAid           0.0         55.61
# Divina Pastora - Dental Insurance - Lead Ads                4.0         42.73
# Divina Pastora - Seguro Mascotas Lead Ads                   2.0         44.59
# Intereno NL - Messenger                                     3.0         37.02
# Intereno NL - RSP A/B test                                  8.0         60.64
# Museum Volkenkunde Like                                     5.0          7.02
# Twin Promotion - Boulogne Sur Mer BEFR - Lead Ads           0.0         82.54
# Twin Promotion - Ibis Brussels Airport BEFR                 0.0         91.50
# Twin Promotion - Ibis Brussels Airport BENL                 0.0         89.49
# Twin Promotion - Les Jardins d'Azur BEFR - lead...          0.0         45.26
# Twin Promotion - Les Jardins d'Azur BENL - lead...          0.0         32.94
# Twin Promotion - Trésors d’Opale BEFR - lead ads            0.0         75.58
# Twin Promotion - Trésors d’Opale BENL - lead ads            0.0         53.88
# Twin Properties - Holiday Suites NieuwPoort Res...          1.0         58.52
# Twin Properties - ibis Knokke BENL - Lead ads               0.0         52.56
# Upstairs BENL - Lead Ads                                    2.0         23.45
# Upstairs BENL - Lead ads - Cities                           7.0          2.63
# Upstairs BENL - QZ Renovatieprofiel v2 - B                  8.0       -103.68
# Upstairs DE                                                 1.0         23.96
# Upstairs DE - Lead Ads                                      8.0         -9.58
# Verisure Services (UK) Limited                             16.0         18.52
# Verisure UK - Cities                                       20.0        -50.46
# Wereldmuseum Rotterdam Like                                 4.0        -24.19
# Compare & Connect - Lead ads - Voucher AU UD                NaN           NaN
# Intereno NL - LA Brochure Inspiratie                        NaN           NaN
# Intereno NL - LA Brochure Tips                              NaN           NaN
# Intereno NL - LA Brochure Tips [Cities]                     NaN           NaN
# Intereno NL - RSP                                           NaN           NaN
# Twin Properties - Les Jardins d'Azur BENL - lea...          NaN           NaN
# Twin Properties - Trésors d’Opale BEFR - lead ads           NaN           NaN
# Twin Properties BEFR - Holiday Suites NieuwPoor...          NaN           NaN
# Upstairs BENL - QZ Renovatieprofiel v2                      NaN           NaN
#
#                                                     Margin % Difference from Previous Week
# campaign_name
# Afrika Museum Like                                                                     NaN
# Compare & Connect - Voucher LEAD ADS - KitchenAid                                      NaN
# Divina Pastora - Dental Insurance - Lead Ads                                          7.58
# Divina Pastora - Seguro Mascotas Lead Ads                                           -10.51
# Intereno NL - Messenger                                                                NaN
# Intereno NL - RSP A/B test                                                           -0.60
# Museum Volkenkunde Like                                                                NaN
# Twin Promotion - Boulogne Sur Mer BEFR - Lead Ads                                      NaN
# Twin Promotion - Ibis Brussels Airport BEFR                                            NaN
# Twin Promotion - Ibis Brussels Airport BENL                                            NaN
# Twin Promotion - Les Jardins d'Azur BEFR - lead...                                     NaN
# Twin Promotion - Les Jardins d'Azur BENL - lead...                                     NaN
# Twin Promotion - Trésors d’Opale BEFR - lead ads                                       NaN
# Twin Promotion - Trésors d’Opale BENL - lead ads                                       NaN
# Twin Properties - Holiday Suites NieuwPoort Res...                                     NaN
# Twin Properties - ibis Knokke BENL - Lead ads                                         0.21
# Upstairs BENL - Lead Ads                                                             60.47
# Upstairs BENL - Lead ads - Cities                                                    -4.87
# Upstairs BENL - QZ Renovatieprofiel v2 - B                                          -63.06
# Upstairs DE                                                                          31.93
# Upstairs DE - Lead Ads                                                               55.54
# Verisure Services (UK) Limited                                                       39.89
# Verisure UK - Cities                                                                   NaN
# Wereldmuseum Rotterdam Like                                                            NaN
# Compare & Connect - Lead ads - Voucher AU UD                                           NaN
# Intereno NL - LA Brochure Inspiratie                                                   NaN
# Intereno NL - LA Brochure Tips                                                         NaN
# Intereno NL - LA Brochure Tips [Cities]                                                NaN
# Intereno NL - RSP                                                                      NaN
# Twin Properties - Les Jardins d'Azur BENL - lea...                                     NaN
# Twin Properties - Trésors d’Opale BEFR - lead ads                                      NaN
# Twin Properties BEFR - Holiday Suites NieuwPoor...                                     NaN
# Upstairs BENL - QZ Renovatieprofiel v2                                                 NaN

# %% [markdown]
# ## Onno Bossen

# %%
df_onno1=df_new.loc[df_new["marketer_name"]=="Onno Bossen"]
df_onno1=df_onno1.groupby(by=['campaign_name']).sum()
df_onno1["margin %"] = df_onno1.apply(woo, axis=1)
df_onno1["margin %"] = df_onno1["margin %"].round(2)

df_onno2=df_prev.loc[df_prev["marketer_name"]=="Onno Bossen"]
df_onno2=df_onno2.groupby(by=['campaign_name']).sum()
df_onno2["margin %"] = df_onno2.apply(woo, axis=1)
df_onno2["margin %"] = df_onno2["margin %"].round(2)

df_onno = df_onno1.merge(df_onno2, how ="outer", on = ["campaign_name"])
df_onno = df_onno[["total_y","margin %_y","total_x","margin %_x"]]
df_onno = df_onno.rename(index=str, columns=cc)

df_onno["Margin % Difference from Previous Week"]=df_onno["Margin % W26"]-(df_onno["Margin % W25"])

df_onno
# Out:
#                                          New Ads W25  Margin % W25  \
# campaign_name
# Care Laser NL - lead ads                         1.0         69.91
# Care Vision AT - LA - Info pack                  NaN           NaN
# Care Vision AT - LP                              NaN           NaN
# Care Vision DE - LA - Info pack                  NaN           NaN
# Care Vision DE - LP                              NaN           NaN
# Medicare Angola NA PT                            1.0         59.48
# Medicare Dental Testers PT NA                    3.0         28.48
# Medicare Familia PT NA                           3.0         28.13
# Medicare Familia PT NA - V2                      7.0         24.65
# Medicare PT - Dental - Lead Ads                  7.0         11.40
# Medicare Vetecare - Lead Ads                     5.0         28.14
# Melhor Alarme PT - NA                            2.0         34.49
# Optical Express DE                               2.0         69.07
# Optical Express DE - Cities                      9.0         83.06
# Optical Express UK                               0.0         80.93
# Optical Express UK - Cities                      0.0         87.05
# Prescan NL - V2                                  3.0         50.08
# Prescan NL - V2 Budget Optimization              6.0         51.44
# Prosegur Spain - Lead Ads                        NaN           NaN
# Teleperformance Online Marketing DE NA           4.0       -100.00
# Teleperformance Recruiting NL - PT NA            2.0         71.38
# Vava onderzoek NL - Boodschappen 2017            0.0         38.05
# Vava onderzoek NL - Boodschappen 2018            0.0         34.48
# Vergelijkhulp BENL - (BesparenKan) - QZ          1.0         30.56
# Vergelijkhulp NL - QZ v2                         0.0         24.23
# Care Vision AT LP                                0.0         44.92
# Care Vision DE                                   0.0         19.88
# Care Vision DE - Info pack - Lead Ads            0.0         38.71
# Lekker Bikes Australia - Lead Ads                2.0         56.66
# Prescan NL - QZ                                  0.0        100.00
#
#                                          New Ads W26  Margin % W26  \
# campaign_name
# Care Laser NL - lead ads                         2.0         64.16
# Care Vision AT - LA - Info pack                  0.0         86.96
# Care Vision AT - LP                              0.0         42.21
# Care Vision DE - LA - Info pack                  0.0         51.83
# Care Vision DE - LP                              2.0        -86.34
# Medicare Angola NA PT                            1.0         56.13
# Medicare Dental Testers PT NA                    2.0         38.13
# Medicare Familia PT NA                           3.0         20.94
# Medicare Familia PT NA - V2                      4.0         22.74
# Medicare PT - Dental - Lead Ads                  6.0         15.62
# Medicare Vetecare - Lead Ads                     2.0         31.70
# Melhor Alarme PT - NA                            2.0         27.87
# Optical Express DE                               2.0         76.24
# Optical Express DE - Cities                      9.0         82.60
# Optical Express UK                               3.0         70.97
# Optical Express UK - Cities                      0.0         75.34
# Prescan NL - V2                                  0.0         61.78
# Prescan NL - V2 Budget Optimization             12.0         48.18
# Prosegur Spain - Lead Ads                        4.0        -52.84
# Teleperformance Online Marketing DE NA           0.0         34.91
# Teleperformance Recruiting NL - PT NA            0.0         82.65
# Vava onderzoek NL - Boodschappen 2017            0.0         40.00
# Vava onderzoek NL - Boodschappen 2018            0.0         34.45
# Vergelijkhulp BENL - (BesparenKan) - QZ          0.0         40.41
# Vergelijkhulp NL - QZ v2                         0.0         37.77
# Care Vision AT LP                                NaN           NaN
# Care Vision DE                                   NaN           NaN
# Care Vision DE - Info pack - Lead Ads            NaN           NaN
# Lekker Bikes Australia - Lead Ads                NaN           NaN
# Prescan NL - QZ                                  NaN           NaN
#
#                                          Margin % Difference from Previous Week
# campaign_name
# Care Laser NL - lead ads                                                  -5.75
# Care Vision AT - LA - Info pack                                             NaN
# Care Vision AT - LP                                                         NaN
# Care Vision DE - LA - Info pack                                             NaN
# Care Vision DE - LP                                                         NaN
# Medicare Angola NA PT                                                     -3.35
# Medicare Dental Testers PT NA                                              9.65
# Medicare Familia PT NA                                                    -7.19
# Medicare Familia PT NA - V2                                               -1.91
# Medicare PT - Dental - Lead Ads                                            4.22
# Medicare Vetecare - Lead Ads                                               3.56
# Melhor Alarme PT - NA                                                     -6.62
# Optical Express DE                                                         7.17
# Optical Express DE - Cities                                               -0.46
# Optical Express UK                                                        -9.96
# Optical Express UK - Cities                                              -11.71
# Prescan NL - V2                                                           11.70
# Prescan NL - V2 Budget Optimization                                       -3.26
# Prosegur Spain - Lead Ads                                                   NaN
# Teleperformance Online Marketing DE NA                                   134.91
# Teleperformance Recruiting NL - PT NA                                     11.27
# Vava onderzoek NL - Boodschappen 2017                                      1.95
# Vava onderzoek NL - Boodschappen 2018                                     -0.03
# Vergelijkhulp BENL - (BesparenKan) - QZ                                    9.85
# Vergelijkhulp NL - QZ v2                                                  13.54
# Care Vision AT LP                                                           NaN
# Care Vision DE                                                              NaN
# Care Vision DE - Info pack - Lead Ads                                       NaN
# Lekker Bikes Australia - Lead Ads                                           NaN
# Prescan NL - QZ                                                             NaN

# %% [markdown]
# ________________

# %% [markdown]
# # NGOs

# %% [markdown]
# ## Abby Listerman

# %%
df_abby1=df_new.loc[df_new["marketer_name"]=="Abby Listerman"]
df_abby1=df_abby1.groupby(by=['campaign_name']).sum()
df_abby1["margin %"] = df_abby1.apply(woo, axis=1)
df_abby1["margin %"] = df_abby1["margin %"].round(2)

df_abby2=df_prev.loc[df_prev["marketer_name"]=="Abby Listerman"]
df_abby2=df_abby2.groupby(by=['campaign_name']).sum()
df_abby2["margin %"] = df_abby2.apply(woo, axis=1)
df_abby2["margin %"] = df_abby2["margin %"].round(2)

df_abby = df_abby1.merge(df_abby2, how ="outer", on = ["campaign_name"])
df_abby = df_abby[["total_y","margin %_y","total_x","margin %_x"]]
df_abby = df_abby.rename(index=str, columns=cc)

df_abby["Margin % Difference from Previous Week"]=df_abby["Margin % W26"]-(df_abby["Margin % W25"])

df_abby
# Out:
#                                           New Ads W25  Margin % W25  \
# campaign_name
# Alannah and Madeline Foundation AU                  6         49.50
# CICC                                                2         60.15
# Coastguard New Zealand - Quiz                       0         55.27
# Greenpeace Taiwan - Antarctic                       1         37.86
# Greenpeace Taiwan - Antarctic - lead ads            3         42.51
# SPCA NZ                                             0         72.21
# Save the Children Australia                        12         35.97
# UNHCR Australia                                     6         47.33
# WWF Germany - Against Coal                          0         76.89
# Wayside Chapel Australia                            0         62.25
#
#                                           New Ads W26  Margin % W26  \
# campaign_name
# Alannah and Madeline Foundation AU                  0         70.41
# CICC                                                0         60.37
# Coastguard New Zealand - Quiz                       0         58.89
# Greenpeace Taiwan - Antarctic                       3         25.37
# Greenpeace Taiwan - Antarctic - lead ads            1         35.73
# SPCA NZ                                             1         67.35
# Save the Children Australia                         3         52.82
# UNHCR Australia                                     4         35.48
# WWF Germany - Against Coal                          0         57.29
# Wayside Chapel Australia                            0         69.83
#
#                                           Margin % Difference from Previous Week
# campaign_name
# Alannah and Madeline Foundation AU                                         20.91
# CICC                                                                        0.22
# Coastguard New Zealand - Quiz                                               3.62
# Greenpeace Taiwan - Antarctic                                             -12.49
# Greenpeace Taiwan - Antarctic - lead ads                                   -6.78
# SPCA NZ                                                                    -4.86
# Save the Children Australia                                                16.85
# UNHCR Australia                                                           -11.85
# WWF Germany - Against Coal                                                -19.60
# Wayside Chapel Australia                                                    7.58

# %% [markdown]
# ## Mimmi Ångström

# %%
df_mimmi1=df_new.loc[df_new["marketer_name"]=="Mimmi Ångström"]
df_mimmi1=df_mimmi1.groupby(by=['campaign_name']).sum()
df_mimmi1["margin %"] = df_mimmi1.apply(woo, axis=1)
df_mimmi1["margin %"] = df_mimmi1["margin %"].round(2)

df_mimmi2=df_prev.loc[df_prev["marketer_name"]=="Mimmi Ångström"]
df_mimmi2=df_mimmi2.groupby(by=['campaign_name']).sum()
df_mimmi2["margin %"] = df_mimmi2.apply(woo, axis=1)
df_mimmi2["margin %"] = df_mimmi2["margin %"].round(2)

df_mimmi = df_mimmi1.merge(df_mimmi2, how ="outer", on = ["campaign_name"])
df_mimmi = df_mimmi[["total_y","margin %_y","total_x","margin %_x"]]
df_mimmi = df_mimmi.rename(index=str, columns=cc)

df_mimmi["Margin % Difference from Previous Week"]=df_mimmi["Margin % W26"]-(df_mimmi["Margin % W25"])

df_mimmi
# Out:
#                                                     New Ads W25  Margin % W25  \
# campaign_name
# Aldeas Infantiles SOS Brasil - Sexual Abuse - L...          0.0         85.83
# Barnfonden - FGM                                            6.0         66.64
# CareFlight - Petition - Lead Ads                            0.0         33.14
# CareFlight - Quiz - About CareFlight                        0.0         59.06
# Centrepoint UK                                              NaN           NaN
# Make A Wish Australia                                      19.0         25.85
# SOS Children's Villages India - Lead Ads                    0.0         81.16
# Save the Children IN - English speaking cities ...          1.0         59.60
# Save the Children IN - Maharashtra - lead ads               2.0         50.02
# Save the children IN - Rest of India - lead ads             2.0         60.80
# UNICEF Turkish National Committee - Yemen - Lea...         10.0         93.87
# Victor Chang - Canvas Ads                                   1.0         21.26
# Victor Chang Institute Australia petition                   2.0         10.09
# WDC Whales and Dolphins - UK                                8.0         82.60
# CareFlight - Quiz - First Aid                               0.0         66.93
# Victor Chang Institute Australia Quiz                       0.0         66.34
#
#                                                     New Ads W26  Margin % W26  \
# campaign_name
# Aldeas Infantiles SOS Brasil - Sexual Abuse - L...          0.0         85.49
# Barnfonden - FGM                                            0.0         75.60
# CareFlight - Petition - Lead Ads                            0.0         42.39
# CareFlight - Quiz - About CareFlight                        0.0         66.30
# Centrepoint UK                                              5.0         71.70
# Make A Wish Australia                                       5.0         52.16
# SOS Children's Villages India - Lead Ads                    0.0         76.66
# Save the Children IN - English speaking cities ...          0.0         52.75
# Save the Children IN - Maharashtra - lead ads               0.0         43.92
# Save the children IN - Rest of India - lead ads             0.0         54.31
# UNICEF Turkish National Committee - Yemen - Lea...          2.0         94.51
# Victor Chang - Canvas Ads                                   0.0        -14.21
# Victor Chang Institute Australia petition                   2.0         46.58
# WDC Whales and Dolphins - UK                                1.0         79.64
# CareFlight - Quiz - First Aid                               NaN           NaN
# Victor Chang Institute Australia Quiz                       NaN           NaN
#
#                                                     Margin % Difference from Previous Week
# campaign_name
# Aldeas Infantiles SOS Brasil - Sexual Abuse - L...                                   -0.34
# Barnfonden - FGM                                                                      8.96
# CareFlight - Petition - Lead Ads                                                      9.25
# CareFlight - Quiz - About CareFlight                                                  7.24
# Centrepoint UK                                                                         NaN
# Make A Wish Australia                                                                26.31
# SOS Children's Villages India - Lead Ads                                             -4.50
# Save the Children IN - English speaking cities ...                                   -6.85
# Save the Children IN - Maharashtra - lead ads                                        -6.10
# Save the children IN - Rest of India - lead ads                                      -6.49
# UNICEF Turkish National Committee - Yemen - Lea...                                    0.64
# Victor Chang - Canvas Ads                                                           -35.47
# Victor Chang Institute Australia petition                                            36.49
# WDC Whales and Dolphins - UK                                                         -2.96
# CareFlight - Quiz - First Aid                                                          NaN
# Victor Chang Institute Australia Quiz                                                  NaN

# %% [markdown]
# ## Marleen Blokker

# %%
df_marleen1=df_new.loc[df_new["marketer_name"]=="Marleen Blokker"]
df_marleen1=df_marleen1.groupby(by=['campaign_name']).sum()
df_marleen1["margin %"] = df_marleen1.apply(woo, axis=1)
df_marleen1["margin %"] = df_marleen1["margin %"].round(2)

df_marleen2=df_prev.loc[df_prev["marketer_name"]=="Marleen Blokker"]
df_marleen2=df_marleen2.groupby(by=['campaign_name']).sum()
df_marleen2["margin %"] = df_marleen2.apply(woo, axis=1)
df_marleen2["margin %"] = df_marleen2["margin %"].round(2)

df_marleen = df_marleen1.merge(df_marleen2, how ="outer", on = ["campaign_name"])
df_marleen = df_marleen[["total_y","margin %_y","total_x","margin %_x"]]
df_marleen = df_marleen.rename(index=str, columns=cc)

df_marleen["Margin % Difference from Previous Week"]=df_marleen["Margin % W26"]-(df_marleen["Margin % W25"])

df_marleen
# Out:
#                                        New Ads W25  Margin % W25  New Ads W26  \
# campaign_name
# CanTeen NZ                                     0.0         14.75          0.0
# Stichting Vluchteling NL - Help                NaN           NaN          1.0
# Greenpeace NL - Wereld zonder plastic          0.0         42.33          NaN
# MSF AU - Sexual Violence                       0.0         30.20          NaN
# Stichting Vluchteling NL - Steun               4.0         44.84          NaN
#
#                                        Margin % W26  \
# campaign_name
# CanTeen NZ                                    100.0
# Stichting Vluchteling NL - Help              -100.0
# Greenpeace NL - Wereld zonder plastic           NaN
# MSF AU - Sexual Violence                        NaN
# Stichting Vluchteling NL - Steun                NaN
#
#                                        Margin % Difference from Previous Week
# campaign_name
# CanTeen NZ                                                              85.25
# Stichting Vluchteling NL - Help                                           NaN
# Greenpeace NL - Wereld zonder plastic                                     NaN
# MSF AU - Sexual Violence                                                  NaN
# Stichting Vluchteling NL - Steun                                          NaN

# %% [markdown]
# ## Daniela Jacobo Gallardo

# %%
df_daniela1=df_new.loc[df_new["marketer_name"]=="Daniela Jacobo Gallardo"]
df_daniela1=df_daniela1.groupby(by=['campaign_name']).sum()
df_daniela1["margin %"] = df_daniela1.apply(woo, axis=1)
df_daniela1["margin %"] = df_daniela1["margin %"].round(2)

df_daniela2=df_prev.loc[df_prev["marketer_name"]=="Daniela Jacobo Gallardo"]
df_daniela2=df_daniela2.groupby(by=['campaign_name']).sum()
df_daniela2["margin %"] = df_daniela2.apply(woo, axis=1)
df_daniela2["margin %"] = df_daniela2["margin %"].round(2)

df_daniela = df_daniela1.merge(df_daniela2, how ="outer", on = ["campaign_name"])
df_daniela = df_daniela[["total_y","margin %_y","total_x","margin %_x"]]
df_daniela = df_daniela.rename(index=str, columns=cc)

df_daniela["Margin % Difference from Previous Week"]=df_daniela["Margin % W26"]-(df_daniela["Margin % W25"])

df_daniela
# Out:
#                                                     New Ads W25  Margin % W25  \
# campaign_name
# Aldeas Infantiles SOS ES - Child Violence V3                6.0         57.65
# Aldeas Infantiles SOS ES - Hermanos - LP                    2.0        -12.61
# Aldeas Infantiles SOS ES - Hermanos - Lead Ads              6.0         27.57
# Aldeas Infantiles SOS de Espana - Bullying                  0.0          6.95
# Aldeas Infantiles SOS de Espana - Bullying - Ci...          NaN           NaN
# Aldeas Infantiles SOS de Espana - Bullying - Le...          2.0          7.73
# Aldeas Infantiles SOS de Espana - Child violenc...          0.0          8.67
# Aldeas Infantiles SOS de Espana - Syrian refuge...          0.0        -17.12
# Ayuda en Accion de Mexico - Violence Against Women          0.0         59.08
# Ayuda en Acción - Human Trafficking lead ads                0.0         50.86
# Ayuda en Acción - Mexican poverty - Lead ads                0.0         57.36
# Ayuda en Acción Colombia - lead ads                         5.0         66.25
# Ayuda en Acción Peru - middle - Lead Ads                    0.0         57.08
# Barnardos NZ                                                0.0         45.26
# Ethiopiaid                                                  1.0         22.47
# Greenpeace MX - Air quality - Lead Ads                      0.0         41.54
# Greenpeace MX - Pesticides                                  NaN           NaN
# Greenpeace MX - Plastics - Lead ads                         0.0         84.03
# Greenpeace NL - Wereld zonder plastic                       NaN           NaN
# MSF AU - Rohingya                                           0.0         54.27
# MSF AU - Sexual Violence                                    NaN           NaN
# Royal Far West                                              0.0         30.16
# Save the Children MX - Lead Ads                             0.0         80.92
# Save the Children NZ - Daulatdia - Lead Ads                 0.0         26.21
# Stichting Vluchteling NL - Steun                            NaN           NaN
# The Fred Hollows Foundation - Avoidable Blindne...          0.0         11.78
# UNHCR IT - old fasion style                                 0.0         49.32
# Ayuda en Acción - Forced Marriages - LP                     0.0        -17.76
# Ayuda en Acción - Forced Marriages - Lead Ads               0.0         53.81
# Save the Children CO - lead ads                             4.0         82.56
#
#                                                     New Ads W26  Margin % W26  \
# campaign_name
# Aldeas Infantiles SOS ES - Child Violence V3                9.0          8.76
# Aldeas Infantiles SOS ES - Hermanos - LP                    0.0         19.43
# Aldeas Infantiles SOS ES - Hermanos - Lead Ads              0.0         37.97
# Aldeas Infantiles SOS de Espana - Bullying                  0.0         23.51
# Aldeas Infantiles SOS de Espana - Bullying - Ci...         12.0         39.21
# Aldeas Infantiles SOS de Espana - Bullying - Le...          4.0         30.41
# Aldeas Infantiles SOS de Espana - Child violenc...          0.0         16.81
# Aldeas Infantiles SOS de Espana - Syrian refuge...          0.0        -16.46
# Ayuda en Accion de Mexico - Violence Against Women          0.0         75.77
# Ayuda en Acción - Human Trafficking lead ads                0.0         54.64
# Ayuda en Acción - Mexican poverty - Lead ads                0.0         75.23
# Ayuda en Acción Colombia - lead ads                         0.0         81.35
# Ayuda en Acción Peru - middle - Lead Ads                    0.0         56.18
# Barnardos NZ                                                0.0         41.38
# Ethiopiaid                                                  0.0         49.24
# Greenpeace MX - Air quality - Lead Ads                      0.0         58.98
# Greenpeace MX - Pesticides                                  0.0        100.00
# Greenpeace MX - Plastics - Lead ads                         0.0         87.45
# Greenpeace NL - Wereld zonder plastic                       2.0         53.20
# MSF AU - Rohingya                                           0.0         56.44
# MSF AU - Sexual Violence                                    0.0         43.81
# Royal Far West                                              0.0         61.53
# Save the Children MX - Lead Ads                             0.0         83.01
# Save the Children NZ - Daulatdia - Lead Ads                 0.0         34.99
# Stichting Vluchteling NL - Steun                            8.0         12.45
# The Fred Hollows Foundation - Avoidable Blindne...          0.0         45.02
# UNHCR IT - old fasion style                                 0.0         62.50
# Ayuda en Acción - Forced Marriages - LP                     NaN           NaN
# Ayuda en Acción - Forced Marriages - Lead Ads               NaN           NaN
# Save the Children CO - lead ads                             NaN           NaN
#
#                                                     Margin % Difference from Previous Week
# campaign_name
# Aldeas Infantiles SOS ES - Child Violence V3                                        -48.89
# Aldeas Infantiles SOS ES - Hermanos - LP                                             32.04
# Aldeas Infantiles SOS ES - Hermanos - Lead Ads                                       10.40
# Aldeas Infantiles SOS de Espana - Bullying                                           16.56
# Aldeas Infantiles SOS de Espana - Bullying - Ci...                                     NaN
# Aldeas Infantiles SOS de Espana - Bullying - Le...                                   22.68
# Aldeas Infantiles SOS de Espana - Child violenc...                                    8.14
# Aldeas Infantiles SOS de Espana - Syrian refuge...                                    0.66
# Ayuda en Accion de Mexico - Violence Against Women                                   16.69
# Ayuda en Acción - Human Trafficking lead ads                                          3.78
# Ayuda en Acción - Mexican poverty - Lead ads                                         17.87
# Ayuda en Acción Colombia - lead ads                                                  15.10
# Ayuda en Acción Peru - middle - Lead Ads                                             -0.90
# Barnardos NZ                                                                         -3.88
# Ethiopiaid                                                                           26.77
# Greenpeace MX - Air quality - Lead Ads                                               17.44
# Greenpeace MX - Pesticides                                                             NaN
# Greenpeace MX - Plastics - Lead ads                                                   3.42
# Greenpeace NL - Wereld zonder plastic                                                  NaN
# MSF AU - Rohingya                                                                     2.17
# MSF AU - Sexual Violence                                                               NaN
# Royal Far West                                                                       31.37
# Save the Children MX - Lead Ads                                                       2.09
# Save the Children NZ - Daulatdia - Lead Ads                                           8.78
# Stichting Vluchteling NL - Steun                                                       NaN
# The Fred Hollows Foundation - Avoidable Blindne...                                   33.24
# UNHCR IT - old fasion style                                                          13.18
# Ayuda en Acción - Forced Marriages - LP                                                NaN
# Ayuda en Acción - Forced Marriages - Lead Ads                                          NaN
# Save the Children CO - lead ads                                                        NaN

# %% [markdown]
# ## Sam Drentje

# %%
df_sam1=df_new.loc[df_new["marketer_name"]=="Sam Drentje"]
df_sam1=df_sam1.groupby(by=['campaign_name']).sum()
df_sam1["margin %"] = df_sam1.apply(woo, axis=1)
df_sam1["margin %"] = df_sam1["margin %"].round(2)

df_sam2=df_prev.loc[df_prev["marketer_name"]=="Sam Drentje"]
df_sam2=df_sam2.groupby(by=['campaign_name']).sum()
df_sam2["margin %"] = df_sam2.apply(woo, axis=1)
df_sam2["margin %"] = df_sam2["margin %"].round(2)

df_sam = df_sam1.merge(df_sam2, how ="outer", on = ["campaign_name"])
df_sam = df_sam[["total_y","margin %_y","total_x","margin %_x"]]
df_sam = df_sam.rename(index=str, columns=cc)

df_sam["Margin % Difference from Previous Week"]=df_sam["Margin % W26"]-(df_sam["Margin % W25"])

df_sam
# Out:
#                                                     New Ads W25  Margin % W25  \
# campaign_name
# CARE France - Violence against women LP                     NaN           NaN
# ChildFund New Zealand - Violence - Lead Ads                 0.0         19.14
# Childfund New Zealand - Forced Marriage - Lead ads          0.0         14.43
# Stichting DierenLot - ambulance                             0.0        -13.09
# Stichting DierenLot - steunbetuiging - Lead Ads             2.0         20.34
# Stichting DierenLot - steunbetuiging ambulance ...          0.0          8.98
# CareFlight - Petition                                       0.0        100.00
#
#                                                     New Ads W26  Margin % W26  \
# campaign_name
# CARE France - Violence against women LP                     0.0        100.00
# ChildFund New Zealand - Violence - Lead Ads                 0.0         44.61
# Childfund New Zealand - Forced Marriage - Lead ads          0.0         14.03
# Stichting DierenLot - ambulance                             0.0       -100.00
# Stichting DierenLot - steunbetuiging - Lead Ads             2.0         31.09
# Stichting DierenLot - steunbetuiging ambulance ...          0.0         29.07
# CareFlight - Petition                                       NaN           NaN
#
#                                                     Margin % Difference from Previous Week
# campaign_name
# CARE France - Violence against women LP                                                NaN
# ChildFund New Zealand - Violence - Lead Ads                                          25.47
# Childfund New Zealand - Forced Marriage - Lead ads                                   -0.40
# Stichting DierenLot - ambulance                                                     -86.91
# Stichting DierenLot - steunbetuiging - Lead Ads                                      10.75
# Stichting DierenLot - steunbetuiging ambulance ...                                   20.09
# CareFlight - Petition                                                                  NaN

# %% [markdown]
# _______________

# %% [markdown]
# # Hearing Aids

# %% [markdown]
# ## Rob Ransome

# %%
df_rob1=df_new.loc[df_new["marketer_name"]=="Rob Ransome"]
df_rob1=df_rob1.groupby(by=['campaign_name']).sum()
df_rob1["margin %"] = df_rob1.apply(woo, axis=1)
df_rob1["margin %"] = df_rob1["margin %"].round(2)

df_rob2=df_prev.loc[df_prev["marketer_name"]=="Rob Ransome"]
df_rob2=df_rob2.groupby(by=['campaign_name']).sum()
df_rob2["margin %"] = df_rob2.apply(woo, axis=1)
df_rob2["margin %"] = df_rob2["margin %"].round(2)

df_rob = df_rob1.merge(df_rob2, how ="outer", on = ["campaign_name"])
df_rob = df_rob[["total_y","margin %_y","total_x","margin %_x"]]
df_rob = df_rob.rename(index=str, columns=cc)

df_rob["Margin % Difference from Previous Week"]=df_rob["Margin % W26"]-(df_rob["Margin % W25"])

df_rob
# Out:
#                                                     New Ads W25  Margin % W25  \
# campaign_name
# Advanced Hearing                                            0.0         28.51
# Belsono - Belsono Hearing Centers - Experience/...          2.0         32.16
# Belsono - Belsono Hearing Centers - Flexible Ci...          0.0         59.73
# Belsono - Hearing Health - Experience/Demo                  0.0         43.57
# Belsono - Hearing Health - Free Evaluation                 36.0         46.89
# Belsono Hearing Health - USA - Muse iQR - TW - ...          NaN           NaN
# Belsono Hearing Health - USA - Muse iQR - TW - ...          NaN           NaN
# Belsono Hearing Health - USA - Muse iQR - TW - ...          NaN           NaN
# Bloom Hearing Japan - Lead Ads                              NaN           NaN
# Bloom Hearing UK - EVOKE                                    4.0         19.49
# Bloom Hearing UK - beyond - Multiple categories...          NaN           NaN
# Bloom Hearing UK - beyond - RSP v2                          3.0         61.42
# Bloom Hearing UK - beyond RSP - City ads                  141.0         28.99
# Bloom Hearing regular                                       0.0         55.68
# Connect Hearing - Consumer guide LP                         NaN           NaN
# Connect Hearing - Hearing Studio - Lyric                    NaN           NaN
# Connect Hearing Australia - Audeo B                         NaN           NaN
# Connect Hearing Australia - Audeo B - Cities                NaN           NaN
# Connect Hearing Australia - Lyric V2 - B                    NaN           NaN
# Connect Hearing CA                                          0.0         64.01
# Connect Hearing CA - City ads                               NaN           NaN
# Crateful                                                    5.0         44.87
# HearingLife Canada                                          0.0         57.39
# HearingLife City Ads 2.0                                    0.0         78.21
# Helix Hearing Care - QZ V1                                  3.0         -5.32
# Nessa Hearing HK - lead ads                                 0.0         75.28
# Nessa Hearing JP - lead ads                                 0.0         59.71
# Nessa Hearing MY - Lead Ads                                 NaN           NaN
# Nessa Hearing MY - Lead ads ENG                             NaN           NaN
# SayWhat Clinics                                             0.0         55.36
# SayWhat Clinics (FREE EVALUATION)                           0.0         71.54
# Saywhat Free Hearing Evaluation                             NaN           NaN
# Widex Brazil- Rio de Janeiro                                4.0         90.48
# Widex Brazil- Sao Paulo                                     4.0         89.98
# Amplifon DE - ReSound LiNX 3D                               0.0         51.23
# Amplifon ES - ReSound LiNX 3D                               0.0         90.44
# Amplifon Switzerland                                        0.0         69.97
# AudicaoActiva PT - MIC - Lead Ads - New                     5.0         35.45
# AudicaoActiva PT - ReSound - Lead Ads - New                 0.0         39.54
# Belsono - Belsono Hearing Centers - City Ads                0.0       -100.00
# Bonavox                                                     1.0         61.22
# Vitakustik IIC                                              8.0         41.76
# Vitakustik IIC - Lead Ads                                   3.0          8.35
#
#                                                     New Ads W26  Margin % W26  \
# campaign_name
# Advanced Hearing                                            0.0         65.64
# Belsono - Belsono Hearing Centers - Experience/...          1.0         29.19
# Belsono - Belsono Hearing Centers - Flexible Ci...          0.0         69.46
# Belsono - Hearing Health - Experience/Demo                  0.0         36.08
# Belsono - Hearing Health - Free Evaluation                  6.0         43.50
# Belsono Hearing Health - USA - Muse iQR - TW - ...         67.0         73.78
# Belsono Hearing Health - USA - Muse iQR - TW - ...         26.0         52.08
# Belsono Hearing Health - USA - Muse iQR - TW - ...          4.0         58.50
# Bloom Hearing Japan - Lead Ads                              0.0          4.28
# Bloom Hearing UK - EVOKE                                    8.0         33.39
# Bloom Hearing UK - beyond - Multiple categories...          1.0          9.34
# Bloom Hearing UK - beyond - RSP v2                          1.0         64.05
# Bloom Hearing UK - beyond RSP - City ads                   71.0         53.72
# Bloom Hearing regular                                       0.0         62.60
# Connect Hearing - Consumer guide LP                         0.0         38.39
# Connect Hearing - Hearing Studio - Lyric                    0.0         70.59
# Connect Hearing Australia - Audeo B                         3.0         78.33
# Connect Hearing Australia - Audeo B - Cities                0.0         83.74
# Connect Hearing Australia - Lyric V2 - B                    6.0         73.02
# Connect Hearing CA                                          3.0         48.32
# Connect Hearing CA - City ads                              11.0         63.64
# Crateful                                                    2.0         67.37
# HearingLife Canada                                          0.0         61.91
# HearingLife City Ads 2.0                                    0.0         81.42
# Helix Hearing Care - QZ V1                                  1.0         58.77
# Nessa Hearing HK - lead ads                                 0.0         71.14
# Nessa Hearing JP - lead ads                                 0.0         55.98
# Nessa Hearing MY - Lead Ads                                 3.0       -100.00
# Nessa Hearing MY - Lead ads ENG                             3.0         32.33
# SayWhat Clinics                                             0.0         45.45
# SayWhat Clinics (FREE EVALUATION)                           0.0         69.34
# Saywhat Free Hearing Evaluation                             0.0         59.94
# Widex Brazil- Rio de Janeiro                                4.0         94.94
# Widex Brazil- Sao Paulo                                     4.0         95.27
# Amplifon DE - ReSound LiNX 3D                               NaN           NaN
# Amplifon ES - ReSound LiNX 3D                               NaN           NaN
# Amplifon Switzerland                                        NaN           NaN
# AudicaoActiva PT - MIC - Lead Ads - New                     NaN           NaN
# AudicaoActiva PT - ReSound - Lead Ads - New                 NaN           NaN
# Belsono - Belsono Hearing Centers - City Ads                NaN           NaN
# Bonavox                                                     NaN           NaN
# Vitakustik IIC                                              NaN           NaN
# Vitakustik IIC - Lead Ads                                   NaN           NaN
#
#                                                     Margin % Difference from Previous Week
# campaign_name
# Advanced Hearing                                                                     37.13
# Belsono - Belsono Hearing Centers - Experience/...                                   -2.97
# Belsono - Belsono Hearing Centers - Flexible Ci...                                    9.73
# Belsono - Hearing Health - Experience/Demo                                           -7.49
# Belsono - Hearing Health - Free Evaluation                                           -3.39
# Belsono Hearing Health - USA - Muse iQR - TW - ...                                     NaN
# Belsono Hearing Health - USA - Muse iQR - TW - ...                                     NaN
# Belsono Hearing Health - USA - Muse iQR - TW - ...                                     NaN
# Bloom Hearing Japan - Lead Ads                                                         NaN
# Bloom Hearing UK - EVOKE                                                             13.90
# Bloom Hearing UK - beyond - Multiple categories...                                     NaN
# Bloom Hearing UK - beyond - RSP v2                                                    2.63
# Bloom Hearing UK - beyond RSP - City ads                                             24.73
# Bloom Hearing regular                                                                 6.92
# Connect Hearing - Consumer guide LP                                                    NaN
# Connect Hearing - Hearing Studio - Lyric                                               NaN
# Connect Hearing Australia - Audeo B                                                    NaN
# Connect Hearing Australia - Audeo B - Cities                                           NaN
# Connect Hearing Australia - Lyric V2 - B                                               NaN
# Connect Hearing CA                                                                  -15.69
# Connect Hearing CA - City ads                                                          NaN
# Crateful                                                                             22.50
# HearingLife Canada                                                                    4.52
# HearingLife City Ads 2.0                                                              3.21
# Helix Hearing Care - QZ V1                                                           64.09
# Nessa Hearing HK - lead ads                                                          -4.14
# Nessa Hearing JP - lead ads                                                          -3.73
# Nessa Hearing MY - Lead Ads                                                            NaN
# Nessa Hearing MY - Lead ads ENG                                                        NaN
# SayWhat Clinics                                                                      -9.91
# SayWhat Clinics (FREE EVALUATION)                                                    -2.20
# Saywhat Free Hearing Evaluation                                                        NaN
# Widex Brazil- Rio de Janeiro                                                          4.46
# Widex Brazil- Sao Paulo                                                               5.29
# Amplifon DE - ReSound LiNX 3D                                                          NaN
# Amplifon ES - ReSound LiNX 3D                                                          NaN
# Amplifon Switzerland                                                                   NaN
# AudicaoActiva PT - MIC - Lead Ads - New                                                NaN
# AudicaoActiva PT - ReSound - Lead Ads - New                                            NaN
# Belsono - Belsono Hearing Centers - City Ads                                           NaN
# Bonavox                                                                                NaN
# Vitakustik IIC                                                                         NaN
# Vitakustik IIC - Lead Ads                                                              NaN

# %% [markdown]
# ## Robin Ten Hove

# %%
df_robin1=df_new.loc[df_new["marketer_name"]=="Robin Ten Hove"]
df_robin1=df_robin1.groupby(by=['campaign_name']).sum()
df_robin1["margin %"] = df_robin1.apply(woo, axis=1)
df_robin1["margin %"] = df_robin1["margin %"].round(2)

df_robin2=df_prev.loc[df_prev["marketer_name"]=="Robin Ten Hove"]
df_robin2=df_robin2.groupby(by=['campaign_name']).sum()
df_robin2["margin %"] = df_robin2.apply(woo, axis=1)
df_robin2["margin %"] = df_robin2["margin %"].round(2)

df_robin = df_robin1.merge(df_robin2, how ="outer", on = ["campaign_name"])
df_robin = df_robin[["total_y","margin %_y","total_x","margin %_x"]]
df_robin = df_robin.rename(index=str, columns=cc)

df_robin["Margin % Difference from Previous Week"]=df_robin["Margin % W26"]-(df_robin["Margin % W25"])

df_robin
# Out:
#                                                     New Ads W25  Margin % W25  \
# campaign_name
# AudioNova BEFR - White label IIC                            3.0         44.36
# AudioNova BENL - QZ V3 IIC - General                        9.0         19.59
# AudioNova DK - Moxi Now QZ - Cities                        30.0         24.95
# AudioNova DK - Moxi Now QZ - general                        0.0         29.19
# AudioNova IT - Luna C - RSP - Regular                       3.0         35.35
# AudioNova IT - Luna C - RSP - Regular - Split test          3.0         26.52
# Audionova DK - QZ V2                                        NaN           NaN
# GEERS PL                                                    0.0        100.00
# GEERS PL - Luna R-R - QZ                                    0.0         32.81
# GEERS PL - Luna R-R - QZ - Cities                           0.0         25.16
# GEERS PL - Luna R-R - QZ - Split test                       3.0         44.24
# GEERS PL - QZ V1                                            0.0         25.13
# HelloFresh AT - Ausprobieren                                0.0         83.36
# HelloFresh BEFR - Hoger lager KitchenAid                    0.0        100.00
# HelloFresh BEFR - Italiaanse Keukenquiz - Cities            0.0         22.09
# HelloFresh BEFR - Italiaanse Keukenquiz - algemeen          5.0         28.73
# HelloFresh BEFR - Kookenquête Nespresso                     0.0         21.88
# HelloFresh BEFR - Kookenquête Vakantiepark                  5.0         47.55
# HelloFresh BEFR - Pizza Quiz                                0.0         11.35
# HelloFresh BEFR - Prijzenrad KitchenAid 449                 4.0         41.15
# HelloFresh BEFR - Spaanse Keukenquiz                        0.0         32.02
# HelloFresh BENL - Food Festival Quiz                        0.0         18.89
# HelloFresh BENL - Italiaanse Keukenquiz                     0.0         39.59
# HelloFresh BENL - Kookenquête Nespresso                     0.0         48.12
# HelloFresh BENL - Kookenquête Vakantiepark                  0.0         23.96
# HelloFresh BENL - Prijzenrad KitchenAid 449                 4.0         39.79
# HelloFresh BENL - Raad de Pasta                             4.0         51.47
# HelloFresh DE - Tester Gesucht V2                           2.0         51.60
# HelloFresh DE - Tester gesucht V2 - B                       2.0         66.68
# HelloFresh LU - Italiaanse Keukenquiz                       3.0         67.42
# HelloFresh NL - Food Festival Quiz                          0.0         47.46
# HelloFresh NL - Hoger/Lager - KitchenAid                    0.0         60.67
# HelloFresh NL - Kookenquête Nespresso                       1.0         57.66
# HelloFresh NL - Pizza Quiz                                  0.0         53.44
# HelloFresh NL - Prijzenrad KitchenAid 449                   0.0         55.42
# HelloFresh NL - Spaanse Keukenquiz                          0.0         61.86
# HelloFresh NL - Spaanse Keukenquiz - Cities                 0.0         56.84
# HelloFresh NL Italiaanse Keukenquiz                         0.0         67.57
# Miracle Ear Genius 3.0                                      4.0         56.03
# Schoonenberg - Luna 9 - QZ V4                               NaN           NaN
# Schoonenberg - Luna 9 - QZ V5 - A                           0.0         30.31
# Schoonenberg - Luna 9 - QZ V5 - B                           1.0         42.74
# Schoonenberg - Luna 9 - Test                                0.0         51.42
# Schoonenberg - QZ V2                                        NaN           NaN
# Schoonenberg NL - Unitron Insera IIC - QZ V3                NaN           NaN
# AudioNova DK - QZ V3 - Poseidon                             0.0        100.00
# Audionova BENL - QZ V3 IIC - Cities                         0.0         38.20
# Audionova BENL - QZ V4                                      0.0         69.09
# Connect Hearing - Consumer guide LP                         0.0         30.10
# Connect Hearing - Hearing Studio - Lyric                    0.0         68.47
# Connect Hearing Australia - Audeo B                         0.0         77.38
# Connect Hearing Australia - Audeo B - Cities                0.0         84.36
# Connect Hearing Australia - Lyric V2 - B                    0.0         74.31
# Connect Hearing Australia - Virto V2 - Cities               0.0         81.65
# GEERS DE - IIC QZ V3 - New - Cities                         0.0         17.45
# GEERS DE - IIC QZ V3 - New - Regular                        8.0          6.59
# GEERS DE - Testhörer                                        1.0         51.67
# HelloFresh BENL - Italiaanse Keukenquiz - Cities            0.0         -4.19
# HelloFresh BENL - Pizza Quiz                                0.0        100.00
# HelloFresh CAN                                              0.0        100.00
# HelloFresh CH - Tester Gesucht                              0.0        100.00
# HelloFresh DE - Tester Gesucht V2 - Cities                  0.0         35.84
# Schoonenberg - QZ V3 IIC                                    0.0        100.00
#
#                                                     New Ads W26  Margin % W26  \
# campaign_name
# AudioNova BEFR - White label IIC                            3.0         55.61
# AudioNova BENL - QZ V3 IIC - General                        6.0         16.99
# AudioNova DK - Moxi Now QZ - Cities                       153.0         51.72
# AudioNova DK - Moxi Now QZ - general                        0.0         35.61
# AudioNova IT - Luna C - RSP - Regular                       2.0         28.21
# AudioNova IT - Luna C - RSP - Regular - Split test          3.0        -40.16
# Audionova DK - QZ V2                                        0.0        100.00
# GEERS PL                                                    0.0        100.00
# GEERS PL - Luna R-R - QZ                                    0.0         46.30
# GEERS PL - Luna R-R - QZ - Cities                           0.0         18.54
# GEERS PL - Luna R-R - QZ - Split test                       3.0         72.67
# GEERS PL - QZ V1                                            0.0         52.34
# HelloFresh AT - Ausprobieren                                0.0         82.66
# HelloFresh BEFR - Hoger lager KitchenAid                    0.0        100.00
# HelloFresh BEFR - Italiaanse Keukenquiz - Cities            0.0         39.75
# HelloFresh BEFR - Italiaanse Keukenquiz - algemeen          5.0         46.73
# HelloFresh BEFR - Kookenquête Nespresso                     0.0         41.24
# HelloFresh BEFR - Kookenquête Vakantiepark                  4.0         37.62
# HelloFresh BEFR - Pizza Quiz                                0.0         37.72
# HelloFresh BEFR - Prijzenrad KitchenAid 449                 4.0         31.82
# HelloFresh BEFR - Spaanse Keukenquiz                        0.0         52.58
# HelloFresh BENL - Food Festival Quiz                        0.0         21.38
# HelloFresh BENL - Italiaanse Keukenquiz                     5.0         31.80
# HelloFresh BENL - Kookenquête Nespresso                     0.0         47.43
# HelloFresh BENL - Kookenquête Vakantiepark                  0.0         28.63
# HelloFresh BENL - Prijzenrad KitchenAid 449                 4.0         41.39
# HelloFresh BENL - Raad de Pasta                             3.0         22.64
# HelloFresh DE - Tester Gesucht V2                           6.0         61.60
# HelloFresh DE - Tester gesucht V2 - B                       2.0         60.36
# HelloFresh LU - Italiaanse Keukenquiz                       0.0         51.04
# HelloFresh NL - Food Festival Quiz                          0.0         58.46
# HelloFresh NL - Hoger/Lager - KitchenAid                    0.0         63.69
# HelloFresh NL - Kookenquête Nespresso                       1.0         72.88
# HelloFresh NL - Pizza Quiz                                  0.0         65.32
# HelloFresh NL - Prijzenrad KitchenAid 449                   0.0         64.65
# HelloFresh NL - Spaanse Keukenquiz                          0.0         72.61
# HelloFresh NL - Spaanse Keukenquiz - Cities                 0.0         68.68
# HelloFresh NL Italiaanse Keukenquiz                         0.0         74.57
# Miracle Ear Genius 3.0                                      4.0         68.19
# Schoonenberg - Luna 9 - QZ V4                               0.0         59.53
# Schoonenberg - Luna 9 - QZ V5 - A                           1.0         64.45
# Schoonenberg - Luna 9 - QZ V5 - B                           1.0         66.38
# Schoonenberg - Luna 9 - Test                                0.0         67.81
# Schoonenberg - QZ V2                                        0.0        100.00
# Schoonenberg NL - Unitron Insera IIC - QZ V3               11.0         71.41
# AudioNova DK - QZ V3 - Poseidon                             NaN           NaN
# Audionova BENL - QZ V3 IIC - Cities                         NaN           NaN
# Audionova BENL - QZ V4                                      NaN           NaN
# Connect Hearing - Consumer guide LP                         NaN           NaN
# Connect Hearing - Hearing Studio - Lyric                    NaN           NaN
# Connect Hearing Australia - Audeo B                         NaN           NaN
# Connect Hearing Australia - Audeo B - Cities                NaN           NaN
# Connect Hearing Australia - Lyric V2 - B                    NaN           NaN
# Connect Hearing Australia - Virto V2 - Cities               NaN           NaN
# GEERS DE - IIC QZ V3 - New - Cities                         NaN           NaN
# GEERS DE - IIC QZ V3 - New - Regular                        NaN           NaN
# GEERS DE - Testhörer                                        NaN           NaN
# HelloFresh BENL - Italiaanse Keukenquiz - Cities            NaN           NaN
# HelloFresh BENL - Pizza Quiz                                NaN           NaN
# HelloFresh CAN                                              NaN           NaN
# HelloFresh CH - Tester Gesucht                              NaN           NaN
# HelloFresh DE - Tester Gesucht V2 - Cities                  NaN           NaN
# Schoonenberg - QZ V3 IIC                                    NaN           NaN
#
#                                                     Margin % Difference from Previous Week
# campaign_name
# AudioNova BEFR - White label IIC                                                     11.25
# AudioNova BENL - QZ V3 IIC - General                                                 -2.60
# AudioNova DK - Moxi Now QZ - Cities                                                  26.77
# AudioNova DK - Moxi Now QZ - general                                                  6.42
# AudioNova IT - Luna C - RSP - Regular                                                -7.14
# AudioNova IT - Luna C - RSP - Regular - Split test                                  -66.68
# Audionova DK - QZ V2                                                                   NaN
# GEERS PL                                                                              0.00
# GEERS PL - Luna R-R - QZ                                                             13.49
# GEERS PL - Luna R-R - QZ - Cities                                                    -6.62
# GEERS PL - Luna R-R - QZ - Split test                                                28.43
# GEERS PL - QZ V1                                                                     27.21
# HelloFresh AT - Ausprobieren                                                         -0.70
# HelloFresh BEFR - Hoger lager KitchenAid                                              0.00
# HelloFresh BEFR - Italiaanse Keukenquiz - Cities                                     17.66
# HelloFresh BEFR - Italiaanse Keukenquiz - algemeen                                   18.00
# HelloFresh BEFR - Kookenquête Nespresso                                              19.36
# HelloFresh BEFR - Kookenquête Vakantiepark                                           -9.93
# HelloFresh BEFR - Pizza Quiz                                                         26.37
# HelloFresh BEFR - Prijzenrad KitchenAid 449                                          -9.33
# HelloFresh BEFR - Spaanse Keukenquiz                                                 20.56
# HelloFresh BENL - Food Festival Quiz                                                  2.49
# HelloFresh BENL - Italiaanse Keukenquiz                                              -7.79
# HelloFresh BENL - Kookenquête Nespresso                                              -0.69
# HelloFresh BENL - Kookenquête Vakantiepark                                            4.67
# HelloFresh BENL - Prijzenrad KitchenAid 449                                           1.60
# HelloFresh BENL - Raad de Pasta                                                     -28.83
# HelloFresh DE - Tester Gesucht V2                                                    10.00
# HelloFresh DE - Tester gesucht V2 - B                                                -6.32
# HelloFresh LU - Italiaanse Keukenquiz                                               -16.38
# HelloFresh NL - Food Festival Quiz                                                   11.00
# HelloFresh NL - Hoger/Lager - KitchenAid                                              3.02
# HelloFresh NL - Kookenquête Nespresso                                                15.22
# HelloFresh NL - Pizza Quiz                                                           11.88
# HelloFresh NL - Prijzenrad KitchenAid 449                                             9.23
# HelloFresh NL - Spaanse Keukenquiz                                                   10.75
# HelloFresh NL - Spaanse Keukenquiz - Cities                                          11.84
# HelloFresh NL Italiaanse Keukenquiz                                                   7.00
# Miracle Ear Genius 3.0                                                               12.16
# Schoonenberg - Luna 9 - QZ V4                                                          NaN
# Schoonenberg - Luna 9 - QZ V5 - A                                                    34.14
# Schoonenberg - Luna 9 - QZ V5 - B                                                    23.64
# Schoonenberg - Luna 9 - Test                                                         16.39
# Schoonenberg - QZ V2                                                                   NaN
# Schoonenberg NL - Unitron Insera IIC - QZ V3                                           NaN
# AudioNova DK - QZ V3 - Poseidon                                                        NaN
# Audionova BENL - QZ V3 IIC - Cities                                                    NaN
# Audionova BENL - QZ V4                                                                 NaN
# Connect Hearing - Consumer guide LP                                                    NaN
# Connect Hearing - Hearing Studio - Lyric                                               NaN
# Connect Hearing Australia - Audeo B                                                    NaN
# Connect Hearing Australia - Audeo B - Cities                                           NaN
# Connect Hearing Australia - Lyric V2 - B                                               NaN
# Connect Hearing Australia - Virto V2 - Cities                                          NaN
# GEERS DE - IIC QZ V3 - New - Cities                                                    NaN
# GEERS DE - IIC QZ V3 - New - Regular                                                   NaN
# GEERS DE - Testhörer                                                                   NaN
# HelloFresh BENL - Italiaanse Keukenquiz - Cities                                       NaN
# HelloFresh BENL - Pizza Quiz                                                           NaN
# HelloFresh CAN                                                                         NaN
# HelloFresh CH - Tester Gesucht                                                         NaN
# HelloFresh DE - Tester Gesucht V2 - Cities                                             NaN
# Schoonenberg - QZ V3 IIC                                                               NaN

# %% [markdown]
# ## Philip Snoey Kiwiet

# %%
df_philip1=df_new.loc[df_new["marketer_name"]=="Philip Snoey Kiwiet"]
df_philip1=df_philip1.groupby(by=['campaign_name']).sum()
df_philip1["margin %"] = df_philip1.apply(woo, axis=1)
df_philip1["margin %"] = df_philip1["margin %"].round(2)

df_philip2=df_prev.loc[df_prev["marketer_name"]=="Philip Snoey Kiwiet"]
df_philip2=df_philip2.groupby(by=['campaign_name']).sum()
df_philip2["margin %"] = df_philip2.apply(woo, axis=1)
df_philip2["margin %"] = df_philip2["margin %"].round(2)

df_philip = df_philip1.merge(df_philip2, how ="outer", on = ["campaign_name"])
df_philip = df_philip[["total_y","margin %_y","total_x","margin %_x"]]
df_philip = df_philip.rename(index=str, columns=cc)

df_philip["Margin % Difference from Previous Week"]=df_philip["Margin % W26"]-(df_philip["Margin % W25"])

df_philip
# Out:
#                                New Ads W25  Margin % W25  New Ads W26  \
# campaign_name
# Akoustica Medica                       5.0         62.82            3
# Akoustica Medica - Split test          NaN           NaN            3
#
#                                Margin % W26  \
# campaign_name
# Akoustica Medica                      62.04
# Akoustica Medica - Split test         50.65
#
#                                Margin % Difference from Previous Week
# campaign_name
# Akoustica Medica                                                -0.78
# Akoustica Medica - Split test                                     NaN

# %% [markdown]
# ## Theresa Majic

# %% [markdown]
# No camparison can be displayed for Theresa yet.

# %%
df_theresa1=df_new.loc[df_new["marketer_name"]=="Theresa Majic"]
df_theresa1=df_theresa1.groupby(by=['campaign_name']).sum()
df_theresa1["margin %"] = df_theresa1.apply(woo, axis=1)
df_theresa1["margin %"] = df_theresa1["margin %"].round(2)

#df_theresa2=df_prev.loc[df_prev["marketer_name"]=="Theresa Majic"]
#df_theresa2=df_theresa2.groupby(by=['campaign_name']).sum()
#df_theresa2["margin %"] = df_theresa2.apply(woo, axis=1)
#df_theresa2["margin %"] = df_theresa2["margin %"].round(2)

#df_theresa = df_theresa1.merge(df_theresa2, how ="outer", on = ["campaign_name"])
df_theresa = df_theresa1[["total","margin %","total","margin %"]]
df_theresa = df_theresa.rename(index=str, columns=cc)

#df_theresa["Margin % Difference from Previous Week"]=df_theresa["Margin % W26"]-(df_theresa["Margin % W25"])

df_theresa
# Out:
#                                              total  margin %  total  margin %
# campaign_name
# Amplifon BEFR - Signia Cellion                   0     62.02      0     62.02
# Amplifon BENL - Signia Cellion                   0     33.40      0     33.40
# Amplifon DE - ReSound LiNX 3D                    0     60.10      0     60.10
# Amplifon ES - ReSound LiNX 3D                    0     92.03      0     92.03
# Amplifon Switzerland                             0     62.95      0     62.95
# AudicaoActiva PT - MIC - Lead Ads - New          2     19.74      2     19.74
# AudicaoActiva PT - ReSound - Lead Ads - New      3     31.07      3     31.07
# Blackberry Hearing                              11     54.26     11     54.26
# Bonavox                                          3     49.74      3     49.74
# GEERS DE - IIC QZ V3 - New - Cities              0     21.25      0     21.25
# GEERS DE - IIC QZ V3 - New - Regular             5     20.22      5     20.22
# Vitakustik IIC                                   3     50.01      3     50.01
# Vitakustik IIC - Lead Ads                        1     77.47      1     77.47

# %%
# %%html
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
# Out:
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
